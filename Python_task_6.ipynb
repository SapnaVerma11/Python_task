# %% [markdown]
# # Task 6

# %% [markdown]
# Adding an element to  tuple

# %%
tup1 = (68,56,79,"Machine learning",56.7,True)
list1 = list(tup1)
list1[4] = "Deep learning"
list1 = tuple(list1)
print(list1)
# Out:
# (68, 56, 79, 'Machine learning', 'Deep learning', True)

# %% [markdown]
# Removing an element from tuple

# %%
tup2 = (False,"Data Science",97,65.7,86,"hello")
list2 = list(tup2)
list2.remove("hello")
list2 = tuple(list2)
print(list2)
# Out:
# (False, 'Data Science', 97, 65.7, 86)
